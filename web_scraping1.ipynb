# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
## from mathematicians import simple_get
##raw_html = simple_get('https://realpython.com/blog/')
##len(raw_html)


##no_html = simple_get('https://realpython.com/blog/nope-not-gonna-find-it')
##no_html is None
##True
# Out:
# 603251

# %%
raw_html = simple_get('https://libgen.is/')
len(raw_html)
# Out:
# 46196

# %%
 raw_html = simple_get('https://libgen.is/')
 html = BeautifulSoup(raw_html, 'html.parser')
 for i, li in enumerate(html.select('li')):
        print(i, li.text)
# Out:
# 0 RU
#
# 1 FORUM
#
#
# Sitemap
# Error report
#
#
#
# 2 DOWNLOAD
#
#
# Mirrors
# Gen.lib.rus.ec
# Libgen.lc
# Libgen.pw
# Z-Library
# BookFI.net
#
#
# P2P
# Torrents
# Usenet (*.nzb)
# Database Dumps
# gen.lib.rus.ec
# libgen.lc
#
#
# Other
# Books catalog (XLS)
# Source (PHP)
# Import local files in LG format
# Libgen Desktop application
#
#
#
# 3 UPLOAD
#
#
#
# Libgen uploader
# Fiction uploader
# Scientific articles uploader
# FTP
#
# 						(Login:password look at the forum sitemap)
#
#
#
#
# 4 LAST
#
#
#
# Last added
# Last modified
# RSS
# API
#
#
#
#
# 5 OTHERS
#
#
#
# Comics
# Fiction
# Magazines
# Standarts
# Full-text search in LG content
#
#
#
#
# 6 TOPICS
#
#
#
# Technology
#
#
#
# Aerospace Equipment
# Automation
# Communication: Telecommunications
# Communication
# Construction
# Construction: Cement Industry
# Construction: Renovation and interior design: Saunas
# Construction: Renovation and interior design
#
#
# Construction: Ventilation and Air Conditioning
# Electronics: Electronics
# Electronics: Fiber Optics
# Electronics: Hardware
# Electronics: Home Electronics
# Electronics: Microprocessor Technology
# Electronics: Radio
#
#
# Electronics: Robotics
# Electronics: Signal Processing
# Electronics: Telecommunications
# Electronics: TV. Video
# Electronics: VLSI
# Electronics
# Energy: Renewable Energy
# Energy
# Food Manufacturing
#
#
# Fuel Technology
# Heat
# industrial equipment and technology
# Industry: Metallurgy
# Instrument
# Light Industry
# Materials
# Mechanical Engineering
# Metallurgy
# Metrology
#
#
# Military equipment: Weapon
# Military equipment
# Missiles
# Nanotechnology
# Oil and Gas Technologies: Pipelines
# Oil and Gas Technologies
# Patent Business. Ingenuity. Innovation
# Publishing
# Refrigeration
#
#
# Regulatory Literature
# Safety and Security
# Space Science
# Transport
# Transportation: Aviation
# Transportation: Cars, motorcycles
# Transportation: Rail
# Transportation: Ships
# Water Treatment
#
#
#
#
# Art
#
#
#
# Cinema
# Design: Architecture
# Graphic Arts
# Music
# Music: Guitar
# Photo
#
#
#
#
# Biology
#
#
#
# Anthropology
# Anthropology: Evolution
# Biostatistics
# Biotechnology
# Biophysics
# Biochemistry
#
#
# Biochemistry: enologist
# Ecology
# Estestvoznananie
# Genetics
# Microbiology
# Molecular
#
#
# Molecular: Bioinformatics
# Plants: Agriculture and Forestry
# Virology
# Zoology
# Zoology:Paleontology
# Zoology: Fish
#
#
#
#
# Business
#
#
#
# Accounting
# E-Commerce
# Logistics
# Management
# Marketing
# Marketing: Advertising
#
#
# Management: Project Management
# MLM
# Responsibility and Business Ethics
# Trading
#
#
#
#
# Chemistry
#
#
#
# Analytical Chemistry
# Chemical
# Inorganic Chemistry
# Materials
#
#
# Organic Chemistry
# Pyrotechnics and explosives
# Pharmacology
# Physical Chemistry
#
#
#
#
#
#
#
#
# Computers
#
#
#
# Algorithms and Data Structures
# Algorithms and Data Structures: Cryptography
# Algorithms and Data Structures: Image Processing
# Algorithms and Data Structures: Pattern Recognition
# Algorithms and Data Structures: Digital watermarks
# Cybernetics
# Cybernetics: ArtificialIntelligence
#
#
# Cryptography
# Databases
# Information Systems
# Information Systems: EC businesses
# Lectures, monographs
# Media
# Networking
# Networking: Internet
# Operating Systems
#
#
# Organization and Data Processing
# Programming
# Programming: Libraries API
# Programming: Games
# Programming: Compilers
# Programming: Modeling languages
# Programming: Programming Languages
# Programs: TeX, LaTeX
#
#
# Security
# Software: Office software
# Software: Adobe Products
# Software: Macromedia Products
# Software: CAD
# Software: Systems: scientific computing
# System Administration
# Web-design
#
#
#
#
# Geography
#
#
#
# Geodesy. Cartography
# Local History
# Local history: Tourism
# Meteorology, Climatology
# Russia
#
#
#
#
# Geology
#
#
#
# Gidrogeology
# Mining
#
#
#
#
# Economy
#
#
#
# Econometrics
# Investing
# Markets
# Mathematical Economics
# Popular
#
#
#
#
# Education
#
#
#
# Elementary
# International Conferences and Symposiums
# Self-help books
# Theses abstracts
#
#
#
#
#
#
#
#
# Jurisprudence
#
#
#
# Criminology, Forensic Science
# Criminology: Court. examination
# Law
#
#
#
#
# Housekeeping, leisure
#
#
#
# Aquaria
# Astrology
# Beauty, image
# Benefits Homebrew
# Collecting
# Cooking
# Fashion, Jewelry
# Games: Board Games
#
#
# Games: Chess
# Garden, garden
# Handicraft
# Handicraft: Cutting and Sewing
# Hunting and Game Management
# Pet
# Professions and Trades
#
#
#
#
# History
#
#
#
# American Studies
# Archaeology
# Military History
#
#
#
#
# Linguistics
#
#
#
# Comparative Studies
# Dictionaries
# Foreign
# Foreign: English
# Foreign: French
#
#
# Linguistics
# Rhetoric
# Russian Language
# Stylistics
#
#
#
#
#
#
#
#
# Literature
#
#
#
# Children
# Comics
# Detective
# Fantasy
# Fiction
#
#
# Folklore
# Library Literary
# Poetry
# Prose
#
#
#
#
# Mathematics
#
#
#
# Algebra
# Algebra: Linear Algebra
# Algorithms and Data Structures
# Analysis
# Applied Mathematics
# Automatic Control Theory
# Combinatorics
# Computational Mathematics
#
#
# Computer Algebra
# Continued fractions
# Differential Equations
# Discrete Mathematics
# Dynamical Systems
# Elementary
# Functional Analysis
# Fuzzy Logic and Applications
# Game Theory
#
#
# Geometry and Topology
# Graph Theory
# Lectures
# Logic
# Mathematical Physics
# Mathematical Statistics
# Number Theory
# Numerical Analysis
# Operator Theory
#
#
# Optimal control
# Optimization. Operations Research.
# Probability
# Puzzle
# Symmetry and group
# The complex variable
# Wavelets and signal processing
#
#
#
#
# Medicine
#
#
#
# Anatomy and physiology
# Anesthesiology and Intensive Care
# Cardiology
# Chinese Medicine
# Clinical Medicine
# Dentistry, Orthodontics
#
#
# Diabetes
# Diseases: Internal Medicine
# Diseases
# Endocrinology
# ENT
# Epidemiology
# Feng Shui
# Histology
#
#
# Homeopathy
# Immunology
# Infectious diseases
# Molecular Medicine
# Natural Medicine
# Neurology
# Oncology
# Ophthalmology
#
#
# Pediatrics
# Pharmacology
# Popular scientific literature
# Surgery, Orthopedics
# Therapy
# Trial
# Yoga
#
#
#
#
# Other Social Sciences
#
#
#
# Cultural
# Ethnography
# Journalism, Media
# Politics
# Politics: International Relations
#
#
# Philosophy
# Philosophy: Critical Thinking
# Sociology
#
#
#
#
# Physics
#
#
#
# Astronomy: Astrophysics
# Astronomy
# Crystal Physics
# Electricity and Magnetism
# Electrodynamics
# General courses
# Geophysics
# Mechanics
#
#
# Mechanics: Fluid Mechanics
# Mechanics: Mechanics of deformable bodies
# Mechanics: Nonlinear dynamics and chaos
# Mechanics: Oscillations and Waves
#
#
# Mechanics: Strength of Materials
# Mechanics: Theory of Elasticity
# Optics
# Physics of lasers
# Physics of the Atmosphere
# Plasma Physics
#
#
# Quantum Mechanics
# Quantum Physics
# Solid State Physics
# Spectroscopy
# Theory of Relativity and Gravitation
# Thermodynamics and Statistical Mechanics
#
#
#
#
#
#
#
#
# Physical Educ. and Sport
#
#
#
# Bodybuilding
# Bike
# Fencing
# Martial Arts
# Sport fishing
# Survival
#
#
#
#
# Psychology
#
#
#
# The art of communication
# Creative Thinking
# Hypnosis
# Love, erotic
# Neuro-Linguistic Programming
# Pedagogy
#
#
#
#
# Religion
#
#
#
# Buddhism
# Esoteric, Mystery
# Kabbalah
# Orthodoxy
#
#
#
#
# Science (General)
#
#
#
# International Conferences and Symposiums
# Science of Science
# Scientific-popular
# Scientific and popular: Journalism
#
#
#
#
#
#
#
#
# 7 Technology
#
#
#
# Aerospace Equipment
# Automation
# Communication: Telecommunications
# Communication
# Construction
# Construction: Cement Industry
# Construction: Renovation and interior design: Saunas
# Construction: Renovation and interior design
#
#
# Construction: Ventilation and Air Conditioning
# Electronics: Electronics
# Electronics: Fiber Optics
# Electronics: Hardware
# Electronics: Home Electronics
# Electronics: Microprocessor Technology
# Electronics: Radio
#
#
# Electronics: Robotics
# Electronics: Signal Processing
# Electronics: Telecommunications
# Electronics: TV. Video
# Electronics: VLSI
# Electronics
# Energy: Renewable Energy
# Energy
# Food Manufacturing
#
#
# Fuel Technology
# Heat
# industrial equipment and technology
# Industry: Metallurgy
# Instrument
# Light Industry
# Materials
# Mechanical Engineering
# Metallurgy
# Metrology
#
#
# Military equipment: Weapon
# Military equipment
# Missiles
# Nanotechnology
# Oil and Gas Technologies: Pipelines
# Oil and Gas Technologies
# Patent Business. Ingenuity. Innovation
# Publishing
# Refrigeration
#
#
# Regulatory Literature
# Safety and Security
# Space Science
# Transport
# Transportation: Aviation
# Transportation: Cars, motorcycles
# Transportation: Rail
# Transportation: Ships
# Water Treatment
#
#
#
#
# 8 Aerospace Equipment
# 9 Automation
# 10 Communication: Telecommunications
# 11 Communication
# 12 Construction
# 13 Construction: Cement Industry
# 14 Construction: Renovation and interior design: Saunas
# 15 Construction: Renovation and interior design
# 16 Construction: Ventilation and Air Conditioning
# 17 Electronics: Electronics
# 18 Electronics: Fiber Optics
# 19 Electronics: Hardware
# 20 Electronics: Home Electronics
# 21 Electronics: Microprocessor Technology
# 22 Electronics: Radio
# 23 Electronics: Robotics
# 24 Electronics: Signal Processing
# 25 Electronics: Telecommunications
# 26 Electronics: TV. Video
# 27 Electronics: VLSI
# 28 Electronics
# 29 Energy: Renewable Energy
# 30 Energy
# 31 Food Manufacturing
# 32 Fuel Technology
# 33 Heat
# 34 industrial equipment and technology
# 35 Industry: Metallurgy
# 36 Instrument
# 37 Light Industry
# 38 Materials
# 39 Mechanical Engineering
# 40 Metallurgy
# 41 Metrology
# 42 Military equipment: Weapon
# 43 Military equipment
# 44 Missiles
# 45 Nanotechnology
# 46 Oil and Gas Technologies: Pipelines
# 47 Oil and Gas Technologies
# 48 Patent Business. Ingenuity. Innovation
# 49 Publishing
# 50 Refrigeration
# 51 Regulatory Literature
# 52 Safety and Security
# 53 Space Science
# 54 Transport
# 55 Transportation: Aviation
# 56 Transportation: Cars, motorcycles
# 57 Transportation: Rail
# 58 Transportation: Ships
# 59 Water Treatment
# 60 Art
#
#
#
# Cinema
# Design: Architecture
# Graphic Arts
# Music
# Music: Guitar
# Photo
#
#
#
#
# 61 Cinema
# 62 Design: Architecture
# 63 Graphic Arts
# 64 Music
# 65 Music: Guitar
# 66 Photo
# 67 Biology
#
#
#
# Anthropology
# Anthropology: Evolution
# Biostatistics
# Biotechnology
# Biophysics
# Biochemistry
#
#
# Biochemistry: enologist
# Ecology
# Estestvoznananie
# Genetics
# Microbiology
# Molecular
#
#
# Molecular: Bioinformatics
# Plants: Agriculture and Forestry
# Virology
# Zoology
# Zoology:Paleontology
# Zoology: Fish
#
#
#
#
# 68 Anthropology
# 69 Anthropology: Evolution
# 70 Biostatistics
# 71 Biotechnology
# 72 Biophysics
# 73 Biochemistry
# 74 Biochemistry: enologist
# 75 Ecology
# 76 Estestvoznananie
# 77 Genetics
# 78 Microbiology
# 79 Molecular
# 80 Molecular: Bioinformatics
# 81 Plants: Agriculture and Forestry
# 82 Virology
# 83 Zoology
# 84 Zoology:Paleontology
# 85 Zoology: Fish
# 86 Business
#
#
#
# Accounting
# E-Commerce
# Logistics
# Management
# Marketing
# Marketing: Advertising
#
#
# Management: Project Management
# MLM
# Responsibility and Business Ethics
# Trading
#
#
#
#
# 87 Accounting
# 88 E-Commerce
# 89 Logistics
# 90 Management
# 91 Marketing
# 92 Marketing: Advertising
# 93 Management: Project Management
# 94 MLM
# 95 Responsibility and Business Ethics
# 96 Trading
# 97 Chemistry
#
#
#
# Analytical Chemistry
# Chemical
# Inorganic Chemistry
# Materials
#
#
# Organic Chemistry
# Pyrotechnics and explosives
# Pharmacology
# Physical Chemistry
#
#
#
#
# 98 Analytical Chemistry
# 99 Chemical
# 100 Inorganic Chemistry
# 101 Materials
# 102 Organic Chemistry
# 103 Pyrotechnics and explosives
# 104 Pharmacology
# 105 Physical Chemistry
# 106 Computers
#
#
#
# Algorithms and Data Structures
# Algorithms and Data Structures: Cryptography
# Algorithms and Data Structures: Image Processing
# Algorithms and Data Structures: Pattern Recognition
# Algorithms and Data Structures: Digital watermarks
# Cybernetics
# Cybernetics: ArtificialIntelligence
#
#
# Cryptography
# Databases
# Information Systems
# Information Systems: EC businesses
# Lectures, monographs
# Media
# Networking
# Networking: Internet
# Operating Systems
#
#
# Organization and Data Processing
# Programming
# Programming: Libraries API
# Programming: Games
# Programming: Compilers
# Programming: Modeling languages
# Programming: Programming Languages
# Programs: TeX, LaTeX
#
#
# Security
# Software: Office software
# Software: Adobe Products
# Software: Macromedia Products
# Software: CAD
# Software: Systems: scientific computing
# System Administration
# Web-design
#
#
#
#
# 107 Algorithms and Data Structures
# 108 Algorithms and Data Structures: Cryptography
# 109 Algorithms and Data Structures: Image Processing
# 110 Algorithms and Data Structures: Pattern Recognition
# 111 Algorithms and Data Structures: Digital watermarks
# 112 Cybernetics
# 113 Cybernetics: ArtificialIntelligence
# 114 Cryptography
# 115 Databases
# 116 Information Systems
# 117 Information Systems: EC businesses
# 118 Lectures, monographs
# 119 Media
# 120 Networking
# 121 Networking: Internet
# 122 Operating Systems
# 123 Organization and Data Processing
# 124 Programming
# 125 Programming: Libraries API
# 126 Programming: Games
# 127 Programming: Compilers
# 128 Programming: Modeling languages
# 129 Programming: Programming Languages
# 130 Programs: TeX, LaTeX
# 131 Security
# 132 Software: Office software
# 133 Software: Adobe Products
# 134 Software: Macromedia Products
# 135 Software: CAD
# 136 Software: Systems: scientific computing
# 137 System Administration
# 138 Web-design
# 139 Geography
#
#
#
# Geodesy. Cartography
# Local History
# Local history: Tourism
# Meteorology, Climatology
# Russia
#
#
#
#
# 140 Geodesy. Cartography
# 141 Local History
# 142 Local history: Tourism
# 143 Meteorology, Climatology
# 144 Russia
# 145 Geology
#
#
#
# Gidrogeology
# Mining
#
#
#
#
# 146 Gidrogeology
# 147 Mining
# 148 Economy
#
#
#
# Econometrics
# Investing
# Markets
# Mathematical Economics
# Popular
#
#
#
#
# 149 Econometrics
# 150 Investing
# 151 Markets
# 152 Mathematical Economics
# 153 Popular
# 154 Education
#
#
#
# Elementary
# International Conferences and Symposiums
# Self-help books
# Theses abstracts
#
#
#
#
# 155 Elementary
# 156 International Conferences and Symposiums
# 157 Self-help books
# 158 Theses abstracts
# 159 Jurisprudence
#
#
#
# Criminology, Forensic Science
# Criminology: Court. examination
# Law
#
#
#
#
# 160 Criminology, Forensic Science
# 161 Criminology: Court. examination
# 162 Law
# 163 Housekeeping, leisure
#
#
#
# Aquaria
# Astrology
# Beauty, image
# Benefits Homebrew
# Collecting
# Cooking
# Fashion, Jewelry
# Games: Board Games
#
#
# Games: Chess
# Garden, garden
# Handicraft
# Handicraft: Cutting and Sewing
# Hunting and Game Management
# Pet
# Professions and Trades
#
#
#
#
# 164 Aquaria
# 165 Astrology
# 166 Beauty, image
# 167 Benefits Homebrew
# 168 Collecting
# 169 Cooking
# 170 Fashion, Jewelry
# 171 Games: Board Games
# 172 Games: Chess
# 173 Garden, garden
# 174 Handicraft
# 175 Handicraft: Cutting and Sewing
# 176 Hunting and Game Management
# 177 Pet
# 178 Professions and Trades
# 179 History
#
#
#
# American Studies
# Archaeology
# Military History
#
#
#
#
# 180 American Studies
# 181 Archaeology
# 182 Military History
# 183 Linguistics
#
#
#
# Comparative Studies
# Dictionaries
# Foreign
# Foreign: English
# Foreign: French
#
#
# Linguistics
# Rhetoric
# Russian Language
# Stylistics
#
#
#
#
# 184 Comparative Studies
# 185 Dictionaries
# 186 Foreign
# 187 Foreign: English
# 188 Foreign: French
# 189 Linguistics
# 190 Rhetoric
# 191 Russian Language
# 192 Stylistics
# 193 Literature
#
#
#
# Children
# Comics
# Detective
# Fantasy
# Fiction
#
#
# Folklore
# Library Literary
# Poetry
# Prose
#
#
#
#
# 194 Children
# 195 Comics
# 196 Detective
# 197 Fantasy
# 198 Fiction
# 199 Folklore
# 200 Library
# 201 Literary
# 202 Poetry
# 203 Prose
# 204 Mathematics
#
#
#
# Algebra
# Algebra: Linear Algebra
# Algorithms and Data Structures
# Analysis
# Applied Mathematics
# Automatic Control Theory
# Combinatorics
# Computational Mathematics
#
#
# Computer Algebra
# Continued fractions
# Differential Equations
# Discrete Mathematics
# Dynamical Systems
# Elementary
# Functional Analysis
# Fuzzy Logic and Applications
# Game Theory
#
#
# Geometry and Topology
# Graph Theory
# Lectures
# Logic
# Mathematical Physics
# Mathematical Statistics
# Number Theory
# Numerical Analysis
# Operator Theory
#
#
# Optimal control
# Optimization. Operations Research.
# Probability
# Puzzle
# Symmetry and group
# The complex variable
# Wavelets and signal processing
#
#
#
#
# 205 Algebra
# 206 Algebra: Linear Algebra
# 207 Algorithms and Data Structures
# 208 Analysis
# 209 Applied Mathematics
# 210 Automatic Control Theory
# 211 Combinatorics
# 212 Computational Mathematics
# 213 Computer Algebra
# 214 Continued fractions
# 215 Differential Equations
# 216 Discrete Mathematics
# 217 Dynamical Systems
# 218 Elementary
# 219 Functional Analysis
# 220 Fuzzy Logic and Applications
# 221 Game Theory
# 222 Geometry and Topology
# 223 Graph Theory
# 224 Lectures
# 225 Logic
# 226 Mathematical Physics
# 227 Mathematical Statistics
# 228 Number Theory
# 229 Numerical Analysis
# 230 Operator Theory
# 231 Optimal control
# 232 Optimization. Operations Research.
# 233 Probability
# 234 Puzzle
# 235 Symmetry and group
# 236 The complex variable
# 237 Wavelets and signal processing
# 238 Medicine
#
#
#
# Anatomy and physiology
# Anesthesiology and Intensive Care
# Cardiology
# Chinese Medicine
# Clinical Medicine
# Dentistry, Orthodontics
#
#
# Diabetes
# Diseases: Internal Medicine
# Diseases
# Endocrinology
# ENT
# Epidemiology
# Feng Shui
# Histology
#
#
# Homeopathy
# Immunology
# Infectious diseases
# Molecular Medicine
# Natural Medicine
# Neurology
# Oncology
# Ophthalmology
#
#
# Pediatrics
# Pharmacology
# Popular scientific literature
# Surgery, Orthopedics
# Therapy
# Trial
# Yoga
#
#
#
#
# 239 Anatomy and physiology
# 240 Anesthesiology and Intensive Care
# 241 Cardiology
# 242 Chinese Medicine
# 243 Clinical Medicine
# 244 Dentistry, Orthodontics
# 245 Diabetes
# 246 Diseases: Internal Medicine
# 247 Diseases
# 248 Endocrinology
# 249 ENT
# 250 Epidemiology
# 251 Feng Shui
# 252 Histology
# 253 Homeopathy
# 254 Immunology
# 255 Infectious diseases
# 256 Molecular Medicine
# 257 Natural Medicine
# 258 Neurology
# 259 Oncology
# 260 Ophthalmology
# 261 Pediatrics
# 262 Pharmacology
# 263 Popular scientific literature
# 264 Surgery, Orthopedics
# 265 Therapy
# 266 Trial
# 267 Yoga
# 268 Other Social Sciences
#
#
#
# Cultural
# Ethnography
# Journalism, Media
# Politics
# Politics: International Relations
#
#
# Philosophy
# Philosophy: Critical Thinking
# Sociology
#
#
#
#
# 269 Cultural
# 270 Ethnography
# 271 Journalism, Media
# 272 Politics
# 273 Politics: International Relations
# 274 Philosophy
# 275 Philosophy: Critical Thinking
# 276 Sociology
# 277 Physics
#
#
#
# Astronomy: Astrophysics
# Astronomy
# Crystal Physics
# Electricity and Magnetism
# Electrodynamics
# General courses
# Geophysics
# Mechanics
#
#
# Mechanics: Fluid Mechanics
# Mechanics: Mechanics of deformable bodies
# Mechanics: Nonlinear dynamics and chaos
# Mechanics: Oscillations and Waves
#
#
# Mechanics: Strength of Materials
# Mechanics: Theory of Elasticity
# Optics
# Physics of lasers
# Physics of the Atmosphere
# Plasma Physics
#
#
# Quantum Mechanics
# Quantum Physics
# Solid State Physics
# Spectroscopy
# Theory of Relativity and Gravitation
# Thermodynamics and Statistical Mechanics
#
#
#
#
# 278 Astronomy: Astrophysics
# 279 Astronomy
# 280 Crystal Physics
# 281 Electricity and Magnetism
# 282 Electrodynamics
# 283 General courses
# 284 Geophysics
# 285 Mechanics
# 286 Mechanics: Fluid Mechanics
# 287 Mechanics: Mechanics of deformable bodies
# 288 Mechanics: Nonlinear dynamics and chaos
# 289 Mechanics: Oscillations and Waves
# 290 Mechanics: Strength of Materials
# 291 Mechanics: Theory of Elasticity
# 292 Optics
# 293 Physics of lasers
# 294 Physics of the Atmosphere
# 295 Plasma Physics
# 296 Quantum Mechanics
# 297 Quantum Physics
# 298 Solid State Physics
# 299 Spectroscopy
# 300 Theory of Relativity and Gravitation
# 301 Thermodynamics and Statistical Mechanics
# 302 Physical Educ. and Sport
#
#
#
# Bodybuilding
# Bike
# Fencing
# Martial Arts
# Sport fishing
# Survival
#
#
#
#
# 303 Bodybuilding
# 304 Bike
# 305 Fencing
# 306 Martial Arts
# 307 Sport fishing
# 308 Survival
# 309 Psychology
#
#
#
# The art of communication
# Creative Thinking
# Hypnosis
# Love, erotic
# Neuro-Linguistic Programming
# Pedagogy
#
#
#
#
# 310 The art of communication
# 311 Creative Thinking
# 312 Hypnosis
# 313 Love, erotic
# 314 Neuro-Linguistic Programming
# 315 Pedagogy
# 316 Religion
#
#
#
# Buddhism
# Esoteric, Mystery
# Kabbalah
# Orthodoxy
#
#
#
#
# 317 Buddhism
# 318 Esoteric, Mystery
# 319 Kabbalah
# 320 Orthodoxy
# 321 Science (General)
#
#
#
# International Conferences and Symposiums
# Science of Science
# Scientific-popular
# Scientific and popular: Journalism
#
#
#
#
# 322 International Conferences and Symposiums
# 323 Science of Science
# 324 Scientific-popular
# 325 Scientific and popular: Journalism

# %%
raw_html_1 = simple_get('http://www.fabpedigree.com/james/mathmen.htm')
len(raw_html_1)
# Out:
# 414159

# %%
 raw_html_1 = simple_get('https://libgen.is/')
 html = BeautifulSoup(raw_html_1, 'html.parser')
 for i, li in enumerate(html.select('li')):
        print(i, li.text)
# Out:
# 0 RU
#
# 1 FORUM
#
#
# Sitemap
# Error report
#
#
#
# 2 DOWNLOAD
#
#
# Mirrors
# Gen.lib.rus.ec
# Libgen.lc
# Libgen.pw
# Z-Library
# BookFI.net
#
#
# P2P
# Torrents
# Usenet (*.nzb)
# Database Dumps
# gen.lib.rus.ec
# libgen.lc
#
#
# Other
# Books catalog (XLS)
# Source (PHP)
# Import local files in LG format
# Libgen Desktop application
#
#
#
# 3 UPLOAD
#
#
#
# Libgen uploader
# Fiction uploader
# Scientific articles uploader
# FTP
#
# 						(Login:password look at the forum sitemap)
#
#
#
#
# 4 LAST
#
#
#
# Last added
# Last modified
# RSS
# API
#
#
#
#
# 5 OTHERS
#
#
#
# Comics
# Fiction
# Magazines
# Standarts
# Full-text search in LG content
#
#
#
#
# 6 TOPICS
#
#
#
# Technology
#
#
#
# Aerospace Equipment
# Automation
# Communication: Telecommunications
# Communication
# Construction
# Construction: Cement Industry
# Construction: Renovation and interior design: Saunas
# Construction: Renovation and interior design
#
#
# Construction: Ventilation and Air Conditioning
# Electronics: Electronics
# Electronics: Fiber Optics
# Electronics: Hardware
# Electronics: Home Electronics
# Electronics: Microprocessor Technology
# Electronics: Radio
#
#
# Electronics: Robotics
# Electronics: Signal Processing
# Electronics: Telecommunications
# Electronics: TV. Video
# Electronics: VLSI
# Electronics
# Energy: Renewable Energy
# Energy
# Food Manufacturing
#
#
# Fuel Technology
# Heat
# industrial equipment and technology
# Industry: Metallurgy
# Instrument
# Light Industry
# Materials
# Mechanical Engineering
# Metallurgy
# Metrology
#
#
# Military equipment: Weapon
# Military equipment
# Missiles
# Nanotechnology
# Oil and Gas Technologies: Pipelines
# Oil and Gas Technologies
# Patent Business. Ingenuity. Innovation
# Publishing
# Refrigeration
#
#
# Regulatory Literature
# Safety and Security
# Space Science
# Transport
# Transportation: Aviation
# Transportation: Cars, motorcycles
# Transportation: Rail
# Transportation: Ships
# Water Treatment
#
#
#
#
# Art
#
#
#
# Cinema
# Design: Architecture
# Graphic Arts
# Music
# Music: Guitar
# Photo
#
#
#
#
# Biology
#
#
#
# Anthropology
# Anthropology: Evolution
# Biostatistics
# Biotechnology
# Biophysics
# Biochemistry
#
#
# Biochemistry: enologist
# Ecology
# Estestvoznananie
# Genetics
# Microbiology
# Molecular
#
#
# Molecular: Bioinformatics
# Plants: Agriculture and Forestry
# Virology
# Zoology
# Zoology:Paleontology
# Zoology: Fish
#
#
#
#
# Business
#
#
#
# Accounting
# E-Commerce
# Logistics
# Management
# Marketing
# Marketing: Advertising
#
#
# Management: Project Management
# MLM
# Responsibility and Business Ethics
# Trading
#
#
#
#
# Chemistry
#
#
#
# Analytical Chemistry
# Chemical
# Inorganic Chemistry
# Materials
#
#
# Organic Chemistry
# Pyrotechnics and explosives
# Pharmacology
# Physical Chemistry
#
#
#
#
#
#
#
#
# Computers
#
#
#
# Algorithms and Data Structures
# Algorithms and Data Structures: Cryptography
# Algorithms and Data Structures: Image Processing
# Algorithms and Data Structures: Pattern Recognition
# Algorithms and Data Structures: Digital watermarks
# Cybernetics
# Cybernetics: ArtificialIntelligence
#
#
# Cryptography
# Databases
# Information Systems
# Information Systems: EC businesses
# Lectures, monographs
# Media
# Networking
# Networking: Internet
# Operating Systems
#
#
# Organization and Data Processing
# Programming
# Programming: Libraries API
# Programming: Games
# Programming: Compilers
# Programming: Modeling languages
# Programming: Programming Languages
# Programs: TeX, LaTeX
#
#
# Security
# Software: Office software
# Software: Adobe Products
# Software: Macromedia Products
# Software: CAD
# Software: Systems: scientific computing
# System Administration
# Web-design
#
#
#
#
# Geography
#
#
#
# Geodesy. Cartography
# Local History
# Local history: Tourism
# Meteorology, Climatology
# Russia
#
#
#
#
# Geology
#
#
#
# Gidrogeology
# Mining
#
#
#
#
# Economy
#
#
#
# Econometrics
# Investing
# Markets
# Mathematical Economics
# Popular
#
#
#
#
# Education
#
#
#
# Elementary
# International Conferences and Symposiums
# Self-help books
# Theses abstracts
#
#
#
#
#
#
#
#
# Jurisprudence
#
#
#
# Criminology, Forensic Science
# Criminology: Court. examination
# Law
#
#
#
#
# Housekeeping, leisure
#
#
#
# Aquaria
# Astrology
# Beauty, image
# Benefits Homebrew
# Collecting
# Cooking
# Fashion, Jewelry
# Games: Board Games
#
#
# Games: Chess
# Garden, garden
# Handicraft
# Handicraft: Cutting and Sewing
# Hunting and Game Management
# Pet
# Professions and Trades
#
#
#
#
# History
#
#
#
# American Studies
# Archaeology
# Military History
#
#
#
#
# Linguistics
#
#
#
# Comparative Studies
# Dictionaries
# Foreign
# Foreign: English
# Foreign: French
#
#
# Linguistics
# Rhetoric
# Russian Language
# Stylistics
#
#
#
#
#
#
#
#
# Literature
#
#
#
# Children
# Comics
# Detective
# Fantasy
# Fiction
#
#
# Folklore
# Library Literary
# Poetry
# Prose
#
#
#
#
# Mathematics
#
#
#
# Algebra
# Algebra: Linear Algebra
# Algorithms and Data Structures
# Analysis
# Applied Mathematics
# Automatic Control Theory
# Combinatorics
# Computational Mathematics
#
#
# Computer Algebra
# Continued fractions
# Differential Equations
# Discrete Mathematics
# Dynamical Systems
# Elementary
# Functional Analysis
# Fuzzy Logic and Applications
# Game Theory
#
#
# Geometry and Topology
# Graph Theory
# Lectures
# Logic
# Mathematical Physics
# Mathematical Statistics
# Number Theory
# Numerical Analysis
# Operator Theory
#
#
# Optimal control
# Optimization. Operations Research.
# Probability
# Puzzle
# Symmetry and group
# The complex variable
# Wavelets and signal processing
#
#
#
#
# Medicine
#
#
#
# Anatomy and physiology
# Anesthesiology and Intensive Care
# Cardiology
# Chinese Medicine
# Clinical Medicine
# Dentistry, Orthodontics
#
#
# Diabetes
# Diseases: Internal Medicine
# Diseases
# Endocrinology
# ENT
# Epidemiology
# Feng Shui
# Histology
#
#
# Homeopathy
# Immunology
# Infectious diseases
# Molecular Medicine
# Natural Medicine
# Neurology
# Oncology
# Ophthalmology
#
#
# Pediatrics
# Pharmacology
# Popular scientific literature
# Surgery, Orthopedics
# Therapy
# Trial
# Yoga
#
#
#
#
# Other Social Sciences
#
#
#
# Cultural
# Ethnography
# Journalism, Media
# Politics
# Politics: International Relations
#
#
# Philosophy
# Philosophy: Critical Thinking
# Sociology
#
#
#
#
# Physics
#
#
#
# Astronomy: Astrophysics
# Astronomy
# Crystal Physics
# Electricity and Magnetism
# Electrodynamics
# General courses
# Geophysics
# Mechanics
#
#
# Mechanics: Fluid Mechanics
# Mechanics: Mechanics of deformable bodies
# Mechanics: Nonlinear dynamics and chaos
# Mechanics: Oscillations and Waves
#
#
# Mechanics: Strength of Materials
# Mechanics: Theory of Elasticity
# Optics
# Physics of lasers
# Physics of the Atmosphere
# Plasma Physics
#
#
# Quantum Mechanics
# Quantum Physics
# Solid State Physics
# Spectroscopy
# Theory of Relativity and Gravitation
# Thermodynamics and Statistical Mechanics
#
#
#
#
#
#
#
#
# Physical Educ. and Sport
#
#
#
# Bodybuilding
# Bike
# Fencing
# Martial Arts
# Sport fishing
# Survival
#
#
#
#
# Psychology
#
#
#
# The art of communication
# Creative Thinking
# Hypnosis
# Love, erotic
# Neuro-Linguistic Programming
# Pedagogy
#
#
#
#
# Religion
#
#
#
# Buddhism
# Esoteric, Mystery
# Kabbalah
# Orthodoxy
#
#
#
#
# Science (General)
#
#
#
# International Conferences and Symposiums
# Science of Science
# Scientific-popular
# Scientific and popular: Journalism
#
#
#
#
#
#
#
#
# 7 Technology
#
#
#
# Aerospace Equipment
# Automation
# Communication: Telecommunications
# Communication
# Construction
# Construction: Cement Industry
# Construction: Renovation and interior design: Saunas
# Construction: Renovation and interior design
#
#
# Construction: Ventilation and Air Conditioning
# Electronics: Electronics
# Electronics: Fiber Optics
# Electronics: Hardware
# Electronics: Home Electronics
# Electronics: Microprocessor Technology
# Electronics: Radio
#
#
# Electronics: Robotics
# Electronics: Signal Processing
# Electronics: Telecommunications
# Electronics: TV. Video
# Electronics: VLSI
# Electronics
# Energy: Renewable Energy
# Energy
# Food Manufacturing
#
#
# Fuel Technology
# Heat
# industrial equipment and technology
# Industry: Metallurgy
# Instrument
# Light Industry
# Materials
# Mechanical Engineering
# Metallurgy
# Metrology
#
#
# Military equipment: Weapon
# Military equipment
# Missiles
# Nanotechnology
# Oil and Gas Technologies: Pipelines
# Oil and Gas Technologies
# Patent Business. Ingenuity. Innovation
# Publishing
# Refrigeration
#
#
# Regulatory Literature
# Safety and Security
# Space Science
# Transport
# Transportation: Aviation
# Transportation: Cars, motorcycles
# Transportation: Rail
# Transportation: Ships
# Water Treatment
#
#
#
#
# 8 Aerospace Equipment
# 9 Automation
# 10 Communication: Telecommunications
# 11 Communication
# 12 Construction
# 13 Construction: Cement Industry
# 14 Construction: Renovation and interior design: Saunas
# 15 Construction: Renovation and interior design
# 16 Construction: Ventilation and Air Conditioning
# 17 Electronics: Electronics
# 18 Electronics: Fiber Optics
# 19 Electronics: Hardware
# 20 Electronics: Home Electronics
# 21 Electronics: Microprocessor Technology
# 22 Electronics: Radio
# 23 Electronics: Robotics
# 24 Electronics: Signal Processing
# 25 Electronics: Telecommunications
# 26 Electronics: TV. Video
# 27 Electronics: VLSI
# 28 Electronics
# 29 Energy: Renewable Energy
# 30 Energy
# 31 Food Manufacturing
# 32 Fuel Technology
# 33 Heat
# 34 industrial equipment and technology
# 35 Industry: Metallurgy
# 36 Instrument
# 37 Light Industry
# 38 Materials
# 39 Mechanical Engineering
# 40 Metallurgy
# 41 Metrology
# 42 Military equipment: Weapon
# 43 Military equipment
# 44 Missiles
# 45 Nanotechnology
# 46 Oil and Gas Technologies: Pipelines
# 47 Oil and Gas Technologies
# 48 Patent Business. Ingenuity. Innovation
# 49 Publishing
# 50 Refrigeration
# 51 Regulatory Literature
# 52 Safety and Security
# 53 Space Science
# 54 Transport
# 55 Transportation: Aviation
# 56 Transportation: Cars, motorcycles
# 57 Transportation: Rail
# 58 Transportation: Ships
# 59 Water Treatment
# 60 Art
#
#
#
# Cinema
# Design: Architecture
# Graphic Arts
# Music
# Music: Guitar
# Photo
#
#
#
#
# 61 Cinema
# 62 Design: Architecture
# 63 Graphic Arts
# 64 Music
# 65 Music: Guitar
# 66 Photo
# 67 Biology
#
#
#
# Anthropology
# Anthropology: Evolution
# Biostatistics
# Biotechnology
# Biophysics
# Biochemistry
#
#
# Biochemistry: enologist
# Ecology
# Estestvoznananie
# Genetics
# Microbiology
# Molecular
#
#
# Molecular: Bioinformatics
# Plants: Agriculture and Forestry
# Virology
# Zoology
# Zoology:Paleontology
# Zoology: Fish
#
#
#
#
# 68 Anthropology
# 69 Anthropology: Evolution
# 70 Biostatistics
# 71 Biotechnology
# 72 Biophysics
# 73 Biochemistry
# 74 Biochemistry: enologist
# 75 Ecology
# 76 Estestvoznananie
# 77 Genetics
# 78 Microbiology
# 79 Molecular
# 80 Molecular: Bioinformatics
# 81 Plants: Agriculture and Forestry
# 82 Virology
# 83 Zoology
# 84 Zoology:Paleontology
# 85 Zoology: Fish
# 86 Business
#
#
#
# Accounting
# E-Commerce
# Logistics
# Management
# Marketing
# Marketing: Advertising
#
#
# Management: Project Management
# MLM
# Responsibility and Business Ethics
# Trading
#
#
#
#
# 87 Accounting
# 88 E-Commerce
# 89 Logistics
# 90 Management
# 91 Marketing
# 92 Marketing: Advertising
# 93 Management: Project Management
# 94 MLM
# 95 Responsibility and Business Ethics
# 96 Trading
# 97 Chemistry
#
#
#
# Analytical Chemistry
# Chemical
# Inorganic Chemistry
# Materials
#
#
# Organic Chemistry
# Pyrotechnics and explosives
# Pharmacology
# Physical Chemistry
#
#
#
#
# 98 Analytical Chemistry
# 99 Chemical
# 100 Inorganic Chemistry
# 101 Materials
# 102 Organic Chemistry
# 103 Pyrotechnics and explosives
# 104 Pharmacology
# 105 Physical Chemistry
# 106 Computers
#
#
#
# Algorithms and Data Structures
# Algorithms and Data Structures: Cryptography
# Algorithms and Data Structures: Image Processing
# Algorithms and Data Structures: Pattern Recognition
# Algorithms and Data Structures: Digital watermarks
# Cybernetics
# Cybernetics: ArtificialIntelligence
#
#
# Cryptography
# Databases
# Information Systems
# Information Systems: EC businesses
# Lectures, monographs
# Media
# Networking
# Networking: Internet
# Operating Systems
#
#
# Organization and Data Processing
# Programming
# Programming: Libraries API
# Programming: Games
# Programming: Compilers
# Programming: Modeling languages
# Programming: Programming Languages
# Programs: TeX, LaTeX
#
#
# Security
# Software: Office software
# Software: Adobe Products
# Software: Macromedia Products
# Software: CAD
# Software: Systems: scientific computing
# System Administration
# Web-design
#
#
#
#
# 107 Algorithms and Data Structures
# 108 Algorithms and Data Structures: Cryptography
# 109 Algorithms and Data Structures: Image Processing
# 110 Algorithms and Data Structures: Pattern Recognition
# 111 Algorithms and Data Structures: Digital watermarks
# 112 Cybernetics
# 113 Cybernetics: ArtificialIntelligence
# 114 Cryptography
# 115 Databases
# 116 Information Systems
# 117 Information Systems: EC businesses
# 118 Lectures, monographs
# 119 Media
# 120 Networking
# 121 Networking: Internet
# 122 Operating Systems
# 123 Organization and Data Processing
# 124 Programming
# 125 Programming: Libraries API
# 126 Programming: Games
# 127 Programming: Compilers
# 128 Programming: Modeling languages
# 129 Programming: Programming Languages
# 130 Programs: TeX, LaTeX
# 131 Security
# 132 Software: Office software
# 133 Software: Adobe Products
# 134 Software: Macromedia Products
# 135 Software: CAD
# 136 Software: Systems: scientific computing
# 137 System Administration
# 138 Web-design
# 139 Geography
#
#
#
# Geodesy. Cartography
# Local History
# Local history: Tourism
# Meteorology, Climatology
# Russia
#
#
#
#
# 140 Geodesy. Cartography
# 141 Local History
# 142 Local history: Tourism
# 143 Meteorology, Climatology
# 144 Russia
# 145 Geology
#
#
#
# Gidrogeology
# Mining
#
#
#
#
# 146 Gidrogeology
# 147 Mining
# 148 Economy
#
#
#
# Econometrics
# Investing
# Markets
# Mathematical Economics
# Popular
#
#
#
#
# 149 Econometrics
# 150 Investing
# 151 Markets
# 152 Mathematical Economics
# 153 Popular
# 154 Education
#
#
#
# Elementary
# International Conferences and Symposiums
# Self-help books
# Theses abstracts
#
#
#
#
# 155 Elementary
# 156 International Conferences and Symposiums
# 157 Self-help books
# 158 Theses abstracts
# 159 Jurisprudence
#
#
#
# Criminology, Forensic Science
# Criminology: Court. examination
# Law
#
#
#
#
# 160 Criminology, Forensic Science
# 161 Criminology: Court. examination
# 162 Law
# 163 Housekeeping, leisure
#
#
#
# Aquaria
# Astrology
# Beauty, image
# Benefits Homebrew
# Collecting
# Cooking
# Fashion, Jewelry
# Games: Board Games
#
#
# Games: Chess
# Garden, garden
# Handicraft
# Handicraft: Cutting and Sewing
# Hunting and Game Management
# Pet
# Professions and Trades
#
#
#
#
# 164 Aquaria
# 165 Astrology
# 166 Beauty, image
# 167 Benefits Homebrew
# 168 Collecting
# 169 Cooking
# 170 Fashion, Jewelry
# 171 Games: Board Games
# 172 Games: Chess
# 173 Garden, garden
# 174 Handicraft
# 175 Handicraft: Cutting and Sewing
# 176 Hunting and Game Management
# 177 Pet
# 178 Professions and Trades
# 179 History
#
#
#
# American Studies
# Archaeology
# Military History
#
#
#
#
# 180 American Studies
# 181 Archaeology
# 182 Military History
# 183 Linguistics
#
#
#
# Comparative Studies
# Dictionaries
# Foreign
# Foreign: English
# Foreign: French
#
#
# Linguistics
# Rhetoric
# Russian Language
# Stylistics
#
#
#
#
# 184 Comparative Studies
# 185 Dictionaries
# 186 Foreign
# 187 Foreign: English
# 188 Foreign: French
# 189 Linguistics
# 190 Rhetoric
# 191 Russian Language
# 192 Stylistics
# 193 Literature
#
#
#
# Children
# Comics
# Detective
# Fantasy
# Fiction
#
#
# Folklore
# Library Literary
# Poetry
# Prose
#
#
#
#
# 194 Children
# 195 Comics
# 196 Detective
# 197 Fantasy
# 198 Fiction
# 199 Folklore
# 200 Library
# 201 Literary
# 202 Poetry
# 203 Prose
# 204 Mathematics
#
#
#
# Algebra
# Algebra: Linear Algebra
# Algorithms and Data Structures
# Analysis
# Applied Mathematics
# Automatic Control Theory
# Combinatorics
# Computational Mathematics
#
#
# Computer Algebra
# Continued fractions
# Differential Equations
# Discrete Mathematics
# Dynamical Systems
# Elementary
# Functional Analysis
# Fuzzy Logic and Applications
# Game Theory
#
#
# Geometry and Topology
# Graph Theory
# Lectures
# Logic
# Mathematical Physics
# Mathematical Statistics
# Number Theory
# Numerical Analysis
# Operator Theory
#
#
# Optimal control
# Optimization. Operations Research.
# Probability
# Puzzle
# Symmetry and group
# The complex variable
# Wavelets and signal processing
#
#
#
#
# 205 Algebra
# 206 Algebra: Linear Algebra
# 207 Algorithms and Data Structures
# 208 Analysis
# 209 Applied Mathematics
# 210 Automatic Control Theory
# 211 Combinatorics
# 212 Computational Mathematics
# 213 Computer Algebra
# 214 Continued fractions
# 215 Differential Equations
# 216 Discrete Mathematics
# 217 Dynamical Systems
# 218 Elementary
# 219 Functional Analysis
# 220 Fuzzy Logic and Applications
# 221 Game Theory
# 222 Geometry and Topology
# 223 Graph Theory
# 224 Lectures
# 225 Logic
# 226 Mathematical Physics
# 227 Mathematical Statistics
# 228 Number Theory
# 229 Numerical Analysis
# 230 Operator Theory
# 231 Optimal control
# 232 Optimization. Operations Research.
# 233 Probability
# 234 Puzzle
# 235 Symmetry and group
# 236 The complex variable
# 237 Wavelets and signal processing
# 238 Medicine
#
#
#
# Anatomy and physiology
# Anesthesiology and Intensive Care
# Cardiology
# Chinese Medicine
# Clinical Medicine
# Dentistry, Orthodontics
#
#
# Diabetes
# Diseases: Internal Medicine
# Diseases
# Endocrinology
# ENT
# Epidemiology
# Feng Shui
# Histology
#
#
# Homeopathy
# Immunology
# Infectious diseases
# Molecular Medicine
# Natural Medicine
# Neurology
# Oncology
# Ophthalmology
#
#
# Pediatrics
# Pharmacology
# Popular scientific literature
# Surgery, Orthopedics
# Therapy
# Trial
# Yoga
#
#
#
#
# 239 Anatomy and physiology
# 240 Anesthesiology and Intensive Care
# 241 Cardiology
# 242 Chinese Medicine
# 243 Clinical Medicine
# 244 Dentistry, Orthodontics
# 245 Diabetes
# 246 Diseases: Internal Medicine
# 247 Diseases
# 248 Endocrinology
# 249 ENT
# 250 Epidemiology
# 251 Feng Shui
# 252 Histology
# 253 Homeopathy
# 254 Immunology
# 255 Infectious diseases
# 256 Molecular Medicine
# 257 Natural Medicine
# 258 Neurology
# 259 Oncology
# 260 Ophthalmology
# 261 Pediatrics
# 262 Pharmacology
# 263 Popular scientific literature
# 264 Surgery, Orthopedics
# 265 Therapy
# 266 Trial
# 267 Yoga
# 268 Other Social Sciences
#
#
#
# Cultural
# Ethnography
# Journalism, Media
# Politics
# Politics: International Relations
#
#
# Philosophy
# Philosophy: Critical Thinking
# Sociology
#
#
#
#
# 269 Cultural
# 270 Ethnography
# 271 Journalism, Media
# 272 Politics
# 273 Politics: International Relations
# 274 Philosophy
# 275 Philosophy: Critical Thinking
# 276 Sociology
# 277 Physics
#
#
#
# Astronomy: Astrophysics
# Astronomy
# Crystal Physics
# Electricity and Magnetism
# Electrodynamics
# General courses
# Geophysics
# Mechanics
#
#
# Mechanics: Fluid Mechanics
# Mechanics: Mechanics of deformable bodies
# Mechanics: Nonlinear dynamics and chaos
# Mechanics: Oscillations and Waves
#
#
# Mechanics: Strength of Materials
# Mechanics: Theory of Elasticity
# Optics
# Physics of lasers
# Physics of the Atmosphere
# Plasma Physics
#
#
# Quantum Mechanics
# Quantum Physics
# Solid State Physics
# Spectroscopy
# Theory of Relativity and Gravitation
# Thermodynamics and Statistical Mechanics
#
#
#
#
# 278 Astronomy: Astrophysics
# 279 Astronomy
# 280 Crystal Physics
# 281 Electricity and Magnetism
# 282 Electrodynamics
# 283 General courses
# 284 Geophysics
# 285 Mechanics
# 286 Mechanics: Fluid Mechanics
# 287 Mechanics: Mechanics of deformable bodies
# 288 Mechanics: Nonlinear dynamics and chaos
# 289 Mechanics: Oscillations and Waves
# 290 Mechanics: Strength of Materials
# 291 Mechanics: Theory of Elasticity
# 292 Optics
# 293 Physics of lasers
# 294 Physics of the Atmosphere
# 295 Plasma Physics
# 296 Quantum Mechanics
# 297 Quantum Physics
# 298 Solid State Physics
# 299 Spectroscopy
# 300 Theory of Relativity and Gravitation
# 301 Thermodynamics and Statistical Mechanics
# 302 Physical Educ. and Sport
#
#
#
# Bodybuilding
# Bike
# Fencing
# Martial Arts
# Sport fishing
# Survival
#
#
#
#
# 303 Bodybuilding
# 304 Bike
# 305 Fencing
# 306 Martial Arts
# 307 Sport fishing
# 308 Survival
# 309 Psychology
#
#
#
# The art of communication
# Creative Thinking
# Hypnosis
# Love, erotic
# Neuro-Linguistic Programming
# Pedagogy
#
#
#
#
# 310 The art of communication
# 311 Creative Thinking
# 312 Hypnosis
# 313 Love, erotic
# 314 Neuro-Linguistic Programming
# 315 Pedagogy
# 316 Religion
#
#
#
# Buddhism
# Esoteric, Mystery
# Kabbalah
# Orthodoxy
#
#
#
#
# 317 Buddhism
# 318 Esoteric, Mystery
# 319 Kabbalah
# 320 Orthodoxy
# 321 Science (General)
#
#
#
# International Conferences and Symposiums
# Science of Science
# Scientific-popular
# Scientific and popular: Journalism
#
#
#
#
# 322 International Conferences and Symposiums
# 323 Science of Science
# 324 Scientific-popular
# 325 Scientific and popular: Journalism

# %%
def get_names():
    """
    Downloads the page where the list of mathematicians is found
    and returns a list of strings, one per mathematician
    """
    url = 'http://www.fabpedigree.com/james/mathmen.htm'
    response = simple_get(url)

    if response is not None:
        html = BeautifulSoup(response, 'html.parser')
        names = set()
        for li in html.select('li'):
            for name in li.text.split('\n'):
                if len(name) > 0:
                    names.add(name.strip())
        return list(names)

    # Raise an exception if we failed to get any data from the url
    raise Exception('Error retrieving contents at {}'.format(url))

# %%
def get_hits_on_name(name):
    """
    Accepts a `name` of a mathematician and returns the number
    of hits that mathematician's Wikipedia page received in the 
    last 60 days, as an `int`
    """
    # url_root is a template string that is used to build a URL.
    url_root = 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE'
    response = simple_get(url_root.format(name))

    if response is not None:
        html = BeautifulSoup(response, 'html.parser')

        hit_link = [a for a in html.select('a')
                    if a['href'].find('latest-60') > -1]

        if len(hit_link) > 0:
            # Strip commas
            link_text = hit_link[0].text.replace(',', '')
            try:
                # Convert to integer
                return int(link_text)
            except:
                log_error("couldn't parse {} as an `int`".format(link_text))

    log_error('No pageviews found for {}'.format(name))
    return None

# %%
if __name__ == '__main__':
    print('Getting the list of names....')
    names = get_names()
    print('... done.\n')

    results = []

    print('Getting stats for each name....')

    for name in names:
        try:
            hits = get_hits_on_name(name)
            if hits is None:
                hits = -1
            results.append((hits, name))
        except:
            results.append((-1, name))
            log_error('error encountered while processing '
                      '{}, skipping'.format(name))

    print('... done.\n')

    results.sort()
    results.reverse()

    if len(results) > 5:
        top_marks = results[:5]
    else:
        top_marks = results

    print('\nThe most popular mathematicians are:\n')
    for (mark, mathematician) in top_marks:
        print('{} with {} pageviews'.format(mathematician, mark))

    no_results = len([res for res in results if res[0] == -1])
    print('\nBut we did not find results for '
          '{} mathematicians on the list'.format(no_results))
# Out:
# Getting the list of names....
# ... done.
#
# Getting stats for each name....
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Charles Hermite
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Joseph Liouville
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Stefan Banach
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for James C. Maxwell
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Jean-Victor Poncelet
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Thales  of Miletus
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Julius Plücker
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Henri Léon Lebesgue
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Ernst E. Kummer
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Alexandre Grothendieck
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Carl F. Gauss
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Jacques Hadamard
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Arthur Cayley
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Liu Hui
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for George D. Birkhoff
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Blaise Pascal
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Pafnuti Chebyshev
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Johannes Kepler
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Bonaventura Cavalieri
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for François Viète
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Bernhard Riemann
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Panini  of Shalatula
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Diophantus  of Alexandria
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Augustin Cauchy
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Michael F. Atiyah
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for John E. Littlewood
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Peter G. L. Dirichlet
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for David Hilbert
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Marius Sophus Lie
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Richard Dedekind
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Apollonius  of Perga
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Niels Abel
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Jacob Bernoulli
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Évariste Galois
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Felix Christian Klein
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Albert Einstein
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Jakob Steiner
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Henri Poincaré
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for André Weil
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Hermann G. Grassmann
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Alan M. Turing
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for John von Neumann
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Isaac Newton
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Leonardo `Fibonacci'
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Bháscara (II) Áchárya
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Alfred Tarski
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for F. Gotthold Eisenstein
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Joseph-Louis Lagrange
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Euclid  of Alexandria
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Siméon-Denis Poisson
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Girolamo Cardano
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Emmy Noether
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Gaspard Monge
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Archytas  of Tarentum
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Eudoxus  of Cnidus
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Hipparchus  of Nicaea
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Srinivasa Ramanujan
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for L.E.J. Brouwer
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Pierre de Fermat
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Giuseppe Peano
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Christiaan Huygens
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Aryabhata
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Shiing-Shen Chern
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Pierre-Simon Laplace
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Galileo Galilei
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for F.E.J. Émile Borel
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Élie Cartan
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Muhammed al-Khowârizmi
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for John Wallis
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Carl Ludwig Siegel
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Kurt Gödel
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Carl G. J. Jacobi
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Joseph Fourier
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for F. L. Gottlob Frege
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Pythagoras  of Samos
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Johann H. Lambert
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Archimedes
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Georg Cantor
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Brahmagupta
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for William R. Hamilton
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Felix Hausdorff
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for René Descartes
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Karl W. T. Weierstrass
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Leonhard Euler
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Aristotle
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Alhazen ibn al-Haytham
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for John F. Nash, Jr.
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Adrien M. Legendre
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Gottfried W. Leibniz
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Jean-Pierre Serre
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for M. E. Camille Jordan
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for James J. Sylvester
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Omar al-Khayyám
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for George Pólya
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Godfrey H. Hardy
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Jean le Rond d'Alembert
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Atle Selberg
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Andrey N. Kolmogorov
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Johann Bernoulli
# Error during requests to URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE : Invalid URL 'URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE': No schema supplied. Perhaps you meant http://URL_REMOVED_SEE_NOTICE_AT_START_OF_ARTICLE?
# No pageviews found for Hermann K. H. Weyl
# ... done.
#
#
# The most popular mathematicians are:
#
# Évariste Galois with -1 pageviews
# Élie Cartan with -1 pageviews
# William R. Hamilton with -1 pageviews
# Thales  of Miletus with -1 pageviews
# Stefan Banach with -1 pageviews
#
# But we did not find results for 100 mathematicians on the list

# %% [markdown]
# # <!DOCTYPE html>
# <html>
# <head>
#   <title>Contrived Example</title>
# </head>
# <body>
# <p id="eggman"> I am the egg man </p>
# <p id="walrus"> I am the walrus </p>
# </body>
# </html>
